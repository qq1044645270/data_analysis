# %%
import base64
f=open('第五章/前后比较和 AB 测试的不同.png','rb') #二进制方式打开图文件
ls_f=base64.b64encode(f.read()) #读取文件内容，转换为base64编码
f.close()
print(ls_f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-68644dc59fc3> in <module>
#       1 import base64
# ----> 2 f=open('第五章/前后比较和 AB 测试的不同.png','rb') #二进制方式打开图文件
#       3 ls_f=base64.b64encode(f.read()) #读取文件内容，转换为base64编码
#       4 f.close()
#       5 print(ls_f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '第五章/前后比较和 AB 测试的不同.png'

# %% [markdown]
#  ![](data:image/png;base64,...)
